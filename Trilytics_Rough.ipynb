# %% [markdown]
# <a href="https://colab.research.google.com/github/Manan-Parakh/Team_Elk/blob/main/Trilytics_Rough.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# General Libraries
import pandas as pd
import numpy as np
import os
import sys
import sklearn
import pickle

# For Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# For reproducibility
np.random.seed(42)

# To Store the pretty images we create
ROOT = "/content/drive/MyDrive/ Trilytics 24"
PROJECT_NAME = "Images"
IMAGES_PATH = os.path.join(ROOT, PROJECT_NAME)
os.makedirs(IMAGES_PATH, exist_ok = True)

def save_fig(figname, extension = "png", resolution = 300, tight_layout = True):
  path = os.path.join(IMAGES_PATH, figname + '.' + extension)
  if tight_layout:
    plt.tight_layout()
  plt.savefig(path, format = extension, dpi = 300)

# %%
import pandas as pd
sales = pd.read_csv('/content/drive/MyDrive/ Trilytics 24/sales.csv')
store = pd.read_csv('/content/drive/MyDrive/ Trilytics 24/store.csv')
promotions = pd.read_csv('/content/drive/MyDrive/ Trilytics 24/promotions.csv')

# %%
store2 = pd.read_csv('/content/drive/MyDrive/ Trilytics 24/store.csv')

# %% [markdown]
# ## Store

# %%
store2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2452 entries, 0 to 2451
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   STORE_KEY                      2452 non-null   int64
#  1   STORE_NUMBER                   2452 non-null   int64
#  2   ROW_EFFECTIVE_TIMESTAMP        2452 non-null   object
#  3   ROW_EXPIRATION_TIMESTAMP       2452 non-null   object
#  4   STORE_NAME                     2449 non-null   object
#  5   STORE_TYPE_CODE                2452 non-null   object
#  6   STORE_TYPE_NAME                2452 non-null   object
#  7   OPEN_DATE                      2452 non-null   object
#  8   CLOSE_DATE                     2452 non-null   object
#  9   CITY_NAME                      2446 non-null   object
#  10  STATE_CODE                     2449 non-null   object
#  11  STATE_NAME                     2450 non-null   object
#  12  COUNTRY_CODE                   2452 non-null   object
#  13  COUNTRY_NAME                   0 non-null      float64
#  14  TIME_ZONE_NAME                 2450 non-null   object
#  15  DMA_ID                         2448 non-null   float64
#  16  DMA_NAME                       2450 non-null   object
#  17  ROYALTY_RATE                   0 non-null      float64
#  18  STORE_STATUS                   2452 non-null   object
#  19  REGION_ID                      2448 non-null   float64
#  20  REGION_NAME                    2450 non-null   object
#  21  PRIOR_STORE_NUMBER             13 non-null     float64
#  22  STORE_LIVE_DATE                2172 non-null   object
#  23  STORE_FUNCTIONAL_STATUS        2452 non-null   object
#  24  GLOBAL_REGION_NAME             2452 non-null   object
#  25  GLOBAL_REGION_STORE_TYPE_NAME  2452 non-null   object
#  26  AREA_REGION                    2450 non-null   object
#  27  DISPATCH_GO_LIVE_DATE          1973 non-null   object
#  28  DOOR_DASH_GO_LIVE_DATE         1704 non-null   object
#  29  DOOR_DASH_MARKUP_GO_LIVE_DATE  2450 non-null   object
#  30  STORE_CONCEPT_NAME             2001 non-null   object
#  31  UBER_EATS_MARKUP_DATE          2450 non-null   object
#  32  EDW_CREATE_TIMESTAMP           2452 non-null   object
#  33  EDW_MODIFY_TIMESTAMP           2452 non-null   object
# dtypes: float64(5), int64(2), object(27)
# memory usage: 651.4+ KB

# %%
store = store2.iloc[:,[1,5,7,8,9,10,14,15,20,18,23]] ## Not Completed Yet.... Working on it

# %%
store.head()
# Out:
#    STORE_NUMBER STORE_TYPE_CODE   OPEN_DATE  CLOSE_DATE      CITY_NAME  \
# 0          2821            Fran  12/31/1999  12/31/1999    Schenectady
# 1          2822            Fran  12/31/1999  12/31/1999       Palm Bay
# 2          2819            Fran  12/31/1999  12/31/1999  Staten Island
# 3          2820            Fran  12/31/1999  12/31/1999  Huber Heights
# 4          2816            Fran  12/31/1999  12/31/1999      Pell City
#
#   STATE_CODE TIME_ZONE_NAME  DMA_ID REGION_NAME STORE_STATUS  \
# 0         NY        Eastern   555.0       North       Future
# 1         FL        Unknown   561.0   Southeast       Future
# 2         NY        Unknown   501.0       North       Future
# 3         OH        Unknown   542.0       North       Future
# 4         AL        Unknown   630.0   Southeast       Future
#
#   STORE_FUNCTIONAL_STATUS
# 0            Signed Lease
# 1            Signed Lease
# 2            Signed Lease
# 3            Signed Lease
# 4            Signed Lease

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2452 entries, 0 to 2451
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   STORE_NUMBER             2452 non-null   int64
#  1   STORE_TYPE_CODE          2452 non-null   object
#  2   OPEN_DATE                2452 non-null   object
#  3   CLOSE_DATE               2452 non-null   object
#  4   CITY_NAME                2446 non-null   object
#  5   STATE_CODE               2449 non-null   object
#  6   TIME_ZONE_NAME           2450 non-null   object
#  7   DMA_ID                   2448 non-null   float64
#  8   REGION_NAME              2450 non-null   object
#  9   STORE_STATUS             2452 non-null   object
#  10  STORE_FUNCTIONAL_STATUS  2452 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 210.8+ KB

# %%
store['CLOSE_DATE'] = pd.to_datetime(store['CLOSE_DATE'], format='%m/%d/%Y')
# Out:
# <ipython-input-242-d31566bad37a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   store['CLOSE_DATE'] = pd.to_datetime(store['CLOSE_DATE'], format='%m/%d/%Y')

# %%
store[store['CLOSE_DATE'] <= ]
# Out:
# STORE_STATUS
# Active      2005
# Future       277
# Inactive     170
# Name: count, dtype: int64

# %%
store[store['STORE_STATUS'] == 'Inactive']['STORE_NUMBER']
# Out:
# 116        7
# 117       10
# 118      140
# 119       17
# 120       20
#         ...
# 1825     799
# 1826     612
# 2149     610
# 2186    7014
# 2450      -7
# Name: STORE_NUMBER, Length: 170, dtype: int64

# %% [markdown]
# ---

# %%
store2.loc[store['STORE_NUMBER'] ==140]
# Out:
#      STORE_KEY  STORE_NUMBER   ROW_EFFECTIVE_TIMESTAMP  \
# 118        963           140  2024-02-02T02:06:58.408Z
#
#      ROW_EXPIRATION_TIMESTAMP STORE_NAME STORE_TYPE_CODE STORE_TYPE_NAME  \
# 118  2024-02-02T02:06:58.408Z      TX140            Fran       Franchise
#
#      OPEN_DATE CLOSE_DATE CITY_NAME  ... GLOBAL_REGION_NAME  \
# 118  12/9/2003  7/15/2017  MESQUITE  ...           Domestic
#
#     GLOBAL_REGION_STORE_TYPE_NAME       AREA_REGION  DISPATCH_GO_LIVE_DATE  \
# 118             DomesticFranchise  DALLAS-FT. WORTH                    NaN
#
#     DOOR_DASH_GO_LIVE_DATE  DOOR_DASH_MARKUP_GO_LIVE_DATE STORE_CONCEPT_NAME  \
# 118                    NaN                      12/9/2003                NaN
#
#      UBER_EATS_MARKUP_DATE      EDW_CREATE_TIMESTAMP      EDW_MODIFY_TIMESTAMP
# 118              12/9/2003  2023-06-13T20:38:55.210Z  2024-02-02T02:06:58.408Z
#
# [1 rows x 34 columns]

# %% [markdown]
# ## Sales

# %%
sales.head()
# Out:
#    STORE_KEY  STORE_NUMBER   OPEN_DATE  BUSINESS_DATE_KEY BUSINESS_DATE  \
# 0       1402           580   10/5/2011           20230203      2/3/2023
# 1       2104          1323  11/21/2017           20221008     10/8/2022
# 2       1753           969    2/6/2006           20230330     3/30/2023
# 3       2443          1664    2/3/2020           20230307      3/7/2023
# 4       1859          1078   3/11/2016           20221105     11/5/2022
#
#    TEMP_CLOSE_INDICATOR  PROJECTION_INCLUDED_INDICATOR  \
# 0                   0.0                              0
# 1                   0.0                              0
# 2                   0.0                              0
# 3                   0.0                              0
# 4                   0.0                              0
#
#    BUSINESS_DATE_FISCAL_DAY_OF_YEAR  BUSINESS_DATE_FISCAL_YEAR  \
# 0                                34                       2023
# 1                               287                       2022
# 2                                89                       2023
# 3                                66                       2023
# 4                               315                       2022
#
#    COMP_BUSINESS_DATE_FISCAL_YEAR  COMPARABLE_INDICATOR  \
# 0                            2022                     1
# 1                            2021                     1
# 2                            2022                     1
# 3                            2022                     1
# 4                            2021                     1
#
#    TRANSACTION_FINAL_COUNT  NET_SALES_FINAL_USD_AMOUNT  \
# 0                      201                     4161.75
# 1                      249                     5785.30
# 2                      258                     5695.29
# 3                      296                     6597.23
# 4                      188                     4100.34
#
#    PY_TRANSACTION_FINAL_COUNT  PY_NET_SALES_FINAL_USD_AMOUNT
# 0                         144                        2752.42
# 1                         166                        4407.43
# 2                         254                        5930.04
# 3                         153                        3726.12
# 4                         146                        3504.75

# %%
sales['BUSINESS_DATE'] = pd.to_datetime(sales['BUSINESS_DATE'], format='%m/%d/%Y')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632197 entries, 0 to 632196
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         632197 non-null  int64
#  1   STORE_NUMBER                      632197 non-null  int64
#  2   OPEN_DATE                         632197 non-null  object
#  3   BUSINESS_DATE_KEY                 632197 non-null  int64
#  4   BUSINESS_DATE                     632197 non-null  datetime64[ns]
#  5   TEMP_CLOSE_INDICATOR              371985 non-null  float64
#  6   PROJECTION_INCLUDED_INDICATOR     632197 non-null  int64
#  7   BUSINESS_DATE_FISCAL_DAY_OF_YEAR  632197 non-null  int64
#  8   BUSINESS_DATE_FISCAL_YEAR         632197 non-null  int64
#  9   COMP_BUSINESS_DATE_FISCAL_YEAR    632197 non-null  int64
#  10  COMPARABLE_INDICATOR              632197 non-null  int64
#  11  TRANSACTION_FINAL_COUNT           632197 non-null  int64
#  12  NET_SALES_FINAL_USD_AMOUNT        632197 non-null  float64
#  13  PY_TRANSACTION_FINAL_COUNT        632197 non-null  int64
#  14  PY_NET_SALES_FINAL_USD_AMOUNT     632197 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(10), object(1)
# memory usage: 72.3+ MB

# %%
## Dropping the Irrelevant Features
sales_new = sales.iloc[:,[1,2,3,4,6,11,12,13,14]]

# %%
sales_new.head()
# Out:
#    STORE_NUMBER  OPEN_DATE  BUSINESS_DATE_KEY BUSINESS_DATE  \
# 0           580 2011-10-05           20230203    2023-02-03
# 1          1323 2017-11-21           20221008    2022-10-08
# 2           969 2006-02-06           20230330    2023-03-30
# 3          1664 2020-02-03           20230307    2023-03-07
# 4          1078 2016-03-11           20221105    2022-11-05
#
#    PROJECTION_INCLUDED_INDICATOR  TRANSACTION_FINAL_COUNT  \
# 0                              0                      201
# 1                              0                      249
# 2                              0                      258
# 3                              0                      296
# 4                              0                      188
#
#    NET_SALES_FINAL_USD_AMOUNT  PY_TRANSACTION_FINAL_COUNT  \
# 0                     4161.75                         144
# 1                     5785.30                         166
# 2                     5695.29                         254
# 3                     6597.23                         153
# 4                     4100.34                         146
#
#    PY_NET_SALES_FINAL_USD_AMOUNT
# 0                        2752.42
# 1                        4407.43
# 2                        5930.04
# 3                        3726.12
# 4                        3504.75

# %%
sales_new.isna().sum()
# Out:
# STORE_NUMBER                     0
# OPEN_DATE                        0
# BUSINESS_DATE_KEY                0
# BUSINESS_DATE                    0
# PROJECTION_INCLUDED_INDICATOR    0
# TRANSACTION_FINAL_COUNT          0
# NET_SALES_FINAL_USD_AMOUNT       0
# PY_TRANSACTION_FINAL_COUNT       0
# PY_NET_SALES_FINAL_USD_AMOUNT    0
# dtype: int64

# %%
sales_new.dtypes
# Out:
# STORE_NUMBER                              int64
# OPEN_DATE                        datetime64[ns]
# BUSINESS_DATE_KEY                         int64
# BUSINESS_DATE                    datetime64[ns]
# PROJECTION_INCLUDED_INDICATOR             int64
# TRANSACTION_FINAL_COUNT                   int64
# NET_SALES_FINAL_USD_AMOUNT              float64
# PY_TRANSACTION_FINAL_COUNT                int64
# PY_NET_SALES_FINAL_USD_AMOUNT           float64
# dtype: object
